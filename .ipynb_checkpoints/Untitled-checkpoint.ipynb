# %%
f = open("theme_cat.json","r")
data = f.read()
f.close()

# %%
data = eval(data)

# %%
def remove_dupe_dicts(l):
    list_of_strings = [
        json.dumps(d, sort_keys=True)
        for d in l
    ]
    list_of_strings = set(list_of_strings)
    return [
        json.loads(s)
        for s in list_of_strings
      ]
# Out:
# [{'names': 'Rhythm - Multipurpose One/Multi Page Template',
#   'category': 'Site Templates',
#   'sub_category': 'Creative',
#   'price': '$17',
#   'sales': '8.5K',
#   'tags': 'agency, ajax, black, bootstrap, clear, creative, minimalistic, multi-purpose, one page, parallax, portfolio, responsive, rtl, white'},
#  {'names': 'Synergy - Responsive & Interactive HTML Portfolio',
#   'category': 'Site Templates',
#   'sub_category': 'Creative',
#   'price': '$28',
#   'sales': '7.4K',
#   'tags': 'agency, creative, filterable columns portfolio, fullscreen, fullscreen slider, infinite scrolling gallery, isotope, masonry, mediacreed, photographer, responsive, self hosted video'},
#  {'names': 'SmartStart - Responsive HTML5 Template',
#   'category': 'Site Templates',
#   'sub_category': 'Creative',
#   'price': '$17',
#   'sales': '7.2K',
# ...

# %%
32520
